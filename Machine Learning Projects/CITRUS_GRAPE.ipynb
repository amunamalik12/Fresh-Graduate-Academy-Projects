# %%
import pandas as pd
df = pd.read_csv('citrus.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10000 non-null  object
#  1   diameter  10000 non-null  float64
#  2   weight    10000 non-null  float64
#  3   red       10000 non-null  int64
#  4   green     10000 non-null  int64
#  5   blue      10000 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 468.9+ KB

# %%
df.head(10000)
# Out:
#             name  diameter  weight  red  green  blue
# 0         orange      2.96   86.76  172     85     2
# 1         orange      3.91   88.05  166     78     3
# 2         orange      4.42   95.17  156     81     2
# 3         orange      4.47   95.60  163     81     4
# 4         orange      4.48   95.76  161     72     9
# ...          ...       ...     ...  ...    ...   ...
# 9995  grapefruit     15.35  253.89  149     77    20
# 9996  grapefruit     15.41  254.67  148     68     7
# 9997  grapefruit     15.59  256.50  168     82    20
# 9998  grapefruit     15.92  260.14  142     72    11
# 9999  grapefruit     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %%
df.name[df.name == 'orange'] = 0
df.name[df.name == 'grapefruit'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[0, 2.96, 86.76, 172, 85, 2],
#        [0, 3.91, 88.05, 166, 78, 3],
#        [0, 4.42, 95.17, 156, 81, 2],
#        ...,
#        [1, 15.59, 256.5, 168, 82, 20],
#        [1, 15.92, 260.14, 142, 72, 11],
#        [1, 16.45, 261.51, 152, 74, 2]], dtype=object)

# %%
# pilih 4 kolom terakhir sebagai atribut
X = dataset[:,1:6]
# bilangan sebelum koma untuk memilih baris pada dataframe
# bilangan setelah koma untuk memilih kolom pada dataframe

# %%
X
# Out:
# array([[2.96, 86.76, 172, 85, 2],
#        [3.91, 88.05, 166, 78, 3],
#        [4.42, 95.17, 156, 81, 2],
#        ...,
#        [15.59, 256.5, 168, 82, 20],
#        [15.92, 260.14, 142, 72, 11],
#        [16.45, 261.51, 152, 74, 2]], dtype=object)

# %%
y = dataset[:,0]
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=object)

# %%
# Normalization
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.        , 0.        , 0.74025974, 0.63529412, 0.        ],
#        [0.07042254, 0.00738197, 0.66233766, 0.55294118, 0.01851852],
#        [0.10822832, 0.04812589, 0.53246753, 0.58823529, 0.        ],
#        ...,
#        [0.93624907, 0.97133047, 0.68831169, 0.6       , 0.33333333],
#        [0.96071164, 0.99216023, 0.35064935, 0.48235294, 0.16666667],
#        [1.        , 1.        , 0.48051948, 0.50588235, 0.        ]])

# %%
# pisahkan data training dan testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
import numpy as np
 
Y_train = Y_train.astype(np.float32)
Y_test = Y_test.astype(np.float32)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([    
                    Dense(32, activation='relu', input_shape=(5,)),    
                    Dense(32, activation='relu'),    
                    Dense(1, activation='sigmoid'),])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 13s 827us/step - loss: 0.6848 - accuracy: 0.5708
# Epoch 2/100
# 219/219 [==============================] - 0s 904us/step - loss: 0.6307 - accuracy: 0.9021
# Epoch 3/100
# 219/219 [==============================] - 0s 845us/step - loss: 0.5789 - accuracy: 0.9130
# Epoch 4/100
# 219/219 [==============================] - 0s 841us/step - loss: 0.5092 - accuracy: 0.9226
# Epoch 5/100
# 219/219 [==============================] - 0s 842us/step - loss: 0.4186 - accuracy: 0.9235
# Epoch 6/100
# 219/219 [==============================] - 0s 857us/step - loss: 0.3354 - accuracy: 0.9242
# Epoch 7/100
# 219/219 [==============================] - 0s 821us/step - loss: 0.2756 - accuracy: 0.9287
# Epoch 8/100
# Epoch 71/100
# 219/219 [==============================] - 0s 891us/step - loss: 0.1729 - accuracy: 0.9296
# Epoch 72/100
# 219/219 [==============================] - 0s 900us/step - loss: 0.1810 - accuracy: 0.9267
# Epoch 73/100
# 219/219 [==============================] - 0s 897us/step - loss: 0.1858 - accuracy: 0.9252
# Epoch 74/100
# 219/219 [==============================] - 0s 864us/step - loss: 0.1877 - accuracy: 0.9234
# Epoch 75/100
# 219/219 [==============================] - 0s 902us/step - loss: 0.1696 - accuracy: 0.9341
# Epoch 76/100
# 219/219 [==============================] - 0s 852us/step - loss: 0.1695 - accuracy: 0.9305
# Epoch 77/100
# 219/219 [==============================] - 0s 888us/step - loss: 0.1755 - accuracy: 0.9301
# Epoch 78/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1677 - accuracy: 0.9331
# Epoch 79/100
# 219/219 [==============================] - 0s 837us/step - loss: 0.1811 - accuracy: 0.9259
# Epoch 80/100
# 219/219 [==============================] - 0s 825us/step - loss: 0.1747 - accuracy: 0.9298
# Epoch 81/100
# 219/219 [==============================] - 0s 855us/step - loss: 0.1641 - accuracy: 0.9341
# Epoch 82/100
# 219/219 [==============================] - 0s 877us/step - loss: 0.1630 - accuracy: 0.9349
# Epoch 83/100
# 219/219 [==============================] - 0s 931us/step - loss: 0.1715 - accuracy: 0.9299
# Epoch 84/100
# 219/219 [==============================] - 0s 859us/step - loss: 0.1704 - accuracy: 0.9308
# Epoch 85/100
# 219/219 [==============================] - 0s 843us/step - loss: 0.1696 - accuracy: 0.9286
# Epoch 86/100
# 219/219 [==============================] - 0s 794us/step - loss: 0.1817 - accuracy: 0.9204
# Epoch 87/100
# 219/219 [==============================] - 0s 837us/step - loss: 0.1699 - accuracy: 0.9302
# Epoch 88/100
# 219/219 [==============================] - 0s 818us/step - loss: 0.1728 - accuracy: 0.9328
# Epoch 89/100
# 219/219 [==============================] - 0s 980us/step - loss: 0.1672 - accuracy: 0.9318
# Epoch 90/100
# 219/219 [==============================] - 0s 863us/step - loss: 0.1732 - accuracy: 0.9307
# Epoch 91/100
# 219/219 [==============================] - 0s 879us/step - loss: 0.1766 - accuracy: 0.9286
# Epoch 92/100
# 219/219 [==============================] - 0s 862us/step - loss: 0.1729 - accuracy: 0.9285
# Epoch 93/100
# 219/219 [==============================] - 0s 870us/step - loss: 0.1702 - accuracy: 0.9332
# Epoch 94/100
# 219/219 [==============================] - 0s 909us/step - loss: 0.1822 - accuracy: 0.9253
# Epoch 95/100
# 219/219 [==============================] - 0s 868us/step - loss: 0.1670 - accuracy: 0.9285
# Epoch 96/100
# 219/219 [==============================] - 0s 913us/step - loss: 0.1670 - accuracy: 0.9307
# Epoch 97/100
# 219/219 [==============================] - 0s 867us/step - loss: 0.1724 - accuracy: 0.9333
# Epoch 98/100
# 219/219 [==============================] - 0s 963us/step - loss: 0.1753 - accuracy: 0.9294
# Epoch 99/100
# 219/219 [==============================] - 0s 901us/step - loss: 0.1702 - accuracy: 0.9257
# Epoch 100/100
# 219/219 [==============================] - 0s 839us/step - loss: 0.1762 - accuracy: 0.9266

# %%
model.evaluate(X_test, Y_test)
# elemen pertama adalah loss dan elemen kedua adalah akurasi
# Out:
# 94/94 [==============================] - 0s 807us/step - loss: 0.1827 - accuracy: 0.9240
# [0.18272510170936584, 0.9240000247955322]
