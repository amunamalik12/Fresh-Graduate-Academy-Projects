# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
mnist = tf.keras.datasets.mnist

# %%
(gambar_latih, label_latih), (gambar_testing, label_testing) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
import numpy as np
np.set_printoptions(linewidth=200)
import matplotlib.pyplot as plt
plt.imshow(gambar_latih[0])
print(label_latih[0])
# Out:
# 5

# %%
gambar_latih  = gambar_latih / 255.0
gambar_testing = gambar_testing / 255.0

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), 
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu), 
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(gambar_latih, label_latih, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2591 - accuracy: 0.9259
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1145 - accuracy: 0.9661
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0788 - accuracy: 0.9765
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0605 - accuracy: 0.9815
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0458 - accuracy: 0.9858

# %% [markdown]
# # BATCH LOADING

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images  = training_images / 255.0
test_images = test_images / 255.0
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), 
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu), 
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(training_images, training_labels, batch_size=32, epochs=5) #batch loading
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2595 - accuracy: 0.9255
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1136 - accuracy: 0.9667
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0774 - accuracy: 0.9760
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0587 - accuracy: 0.9820
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0450 - accuracy: 0.9862

# %%
model.fit(training_images, training_labels, batch_size=255, epochs=5)
# Out:
# Epoch 1/5
# 236/236 [==============================] - 1s 5ms/step - loss: 0.0232 - accuracy: 0.9943
# Epoch 2/5
# 236/236 [==============================] - 1s 6ms/step - loss: 0.0192 - accuracy: 0.9959
# Epoch 3/5
# 236/236 [==============================] - 1s 5ms/step - loss: 0.0176 - accuracy: 0.9966
# Epoch 4/5
# 236/236 [==============================] - 1s 5ms/step - loss: 0.0164 - accuracy: 0.9967
# Epoch 5/5
# 236/236 [==============================] - 1s 5ms/step - loss: 0.0151 - accuracy: 0.9973

# %%
model.fit(training_images, training_labels, batch_size=10000, epochs=5)
# Out:
# Epoch 1/5
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0131 - accuracy: 0.9980
# Epoch 2/5
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0130 - accuracy: 0.9981
# Epoch 3/5
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0129 - accuracy: 0.9982
# Epoch 4/5
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0128 - accuracy: 0.9982
# Epoch 5/5
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0128 - accuracy: 0.9982

# %%
model.fit(training_images, training_labels, batch_size=1000000000, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 748ms/step - loss: 0.0127 - accuracy: 0.9982
# Epoch 2/5
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0127 - accuracy: 0.9982
# Epoch 3/5
# 1/1 [==============================] - 1s 556ms/step - loss: 0.0127 - accuracy: 0.9982
# Epoch 4/5
# 1/1 [==============================] - 1s 523ms/step - loss: 0.0127 - accuracy: 0.9982
# Epoch 5/5
# 1/1 [==============================] - 1s 510ms/step - loss: 0.0127 - accuracy: 0.9982
